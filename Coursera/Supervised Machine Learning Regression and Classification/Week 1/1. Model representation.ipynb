# %% [markdown]
# # Problem Statement

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# X_Train is the input variable ( size in 1000 sqft)
# Y_Train is the Output variable ( price in 1000s of dollars)

X_Train = np.array([1.0, 2.0])
Y_Train = np.array([300, 500])

print(X_Train)
print(Y_Train)
# Out:
# [1. 2.]
# [300 500]

# %% [markdown]
# ### Number of training examples m

# %%
print(X_Train.shape[0]) # m denotes no of training examples. X_Train.shape[0] gives size of array

# or we can use len() function

print("Lenght of x train is: ",len(X_Train))
# Out:
# 2
# Lenght of x train is:  2

# %% [markdown]
# ### Training example x_i, y_i

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(X_Train[0])
print(X_Train[1])

print(Y_Train[0])
print(Y_Train[1])
# Out:
# 1.0
# 2.0
# 300
# 500

# %% [markdown]
# ### Plotting the Data

# %%
# Plot the data points using Scatter

plt.scatter(X_Train,Y_Train, marker='x', c='r')

# Set title
plt.title("Housing Price")

# Set Y axis label
plt.ylabel("Price (in 1000s of dollars)")
# Set x axis lable

plt.xlabel("Size ( 1000sqft)")

plt.show()

# %% [markdown]
# ### Model function
#
# ![image.png](attachment:image.png)

# %%
w=200
b=100

print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 200
# b: 100

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def compute_model_output(x,w,b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b

    return f_wb

tmp_f_wb = compute_model_output(X_Train, w, b,)

# Plot our model prediction
plt.plot(X_Train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(X_Train, Y_Train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# ### Prediction
#
# Now that we have a model, we can use it to make our original prediction. Let's predict the price of a house with 1200 sqft. Since the units of  𝑥
#   are in 1000's of sqft,  𝑥
#   is 1.2

# %%
w=200
b=100
x_val=1.2

cost_1200ft= w * x_val + b

print(cost_1200ft)
# Out:
# 340.0
